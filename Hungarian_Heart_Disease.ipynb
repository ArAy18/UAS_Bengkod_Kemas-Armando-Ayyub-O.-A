# %% [markdown]
# #Persiapan

# %% [markdown]
# #Intalasi

# %%
import itertools
import pandas as pd
import re
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# #Capstone

# %% [markdown]
# ##1. Pengumpulan Data

# %% [markdown]
# Sumber Dataset : </br>
# https://archive.ics.uci.edu/dataset/45/heart+disease </br>
# Agar lebih mudah di proses maka saya convert terlebih dahulu ke csv

# %%
data = pd.read_csv('/content/processed.hungarian.data.csv')
data.head()
# Out:
#    age  sex  cp trestbps chol fbs restecg thalach exang  oldpeak slope ca  \
# 0   28    1   2      130  132   0       2     185     0      0.0     ?  ?
# 1   29    1   2      120  243   0       0     160     0      0.0     ?  ?
# 2   29    1   2      140    ?   0       0     170     0      0.0     ?  ?
# 3   30    0   1      170  237   0       1     170     0      0.0     ?  ?
# 4   31    0   2      100  219   0       1     150     0      0.0     ?  ?
#
#   thal  num
# 0    ?    0
# 1    ?    0
# 2    ?    0
# 3    6    0
# 4    ?    0

# %%
#dir = 'processed.hungarian.data'
#with open(dir, encoding='Latin1') as file:
#  lines = [line.strip() for line in file]
#lines[0:10]

# %% [markdown]
# ##2. Menelaah Data

# %%
#data = itertools.takewhile(
#  lambda x: len(x) == 14,
#  (' '.join(lines[i:(i + 10)]).split() for i in range(0, len(lines), 10))
#)

#df = pd.DataFrame.from_records(data)
#df = pd.DataFrame(data)
df = data
df.head()
# Out:
#    age  sex  cp trestbps chol fbs restecg thalach exang  oldpeak slope ca  \
# 0   28    1   2      130  132   0       2     185     0      0.0     ?  ?
# 1   29    1   2      120  243   0       0     160     0      0.0     ?  ?
# 2   29    1   2      140    ?   0       0     170     0      0.0     ?  ?
# 3   30    0   1      170  237   0       1     170     0      0.0     ?  ?
# 4   31    0   2      100  219   0       1     150     0      0.0     ?  ?
#
#   thal  num
# 0    ?    0
# 1    ?    0
# 2    ?    0
# 3    6    0
# 4    ?    0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 294 entries, 0 to 293
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       294 non-null    int64
#  1   sex       294 non-null    int64
#  2   cp        294 non-null    int64
#  3   trestbps  294 non-null    object
#  4   chol      294 non-null    object
#  5   fbs       294 non-null    object
#  6   restecg   294 non-null    object
#  7   thalach   294 non-null    object
#  8   exang     294 non-null    object
#  9   oldpeak   294 non-null    float64
#  10  slope     294 non-null    object
#  11  ca        294 non-null    object
#  12  thal      294 non-null    object
#  13  num       294 non-null    int64
# dtypes: float64(1), int64(4), object(9)
# memory usage: 32.3+ KB

# %%
df.head()
# Out:
#    age  sex  cp trestbps chol fbs restecg thalach exang  oldpeak slope ca  \
# 0   28    1   2      130  132   0       2     185     0      0.0     ?  ?
# 1   29    1   2      120  243   0       0     160     0      0.0     ?  ?
# 2   29    1   2      140    ?   0       0     170     0      0.0     ?  ?
# 3   30    0   1      170  237   0       1     170     0      0.0     ?  ?
# 4   31    0   2      100  219   0       1     150     0      0.0     ?  ?
#
#   thal  num
# 0    ?    0
# 1    ?    0
# 2    ?    0
# 3    6    0
# 4    ?    0

# %% [markdown]
# ##3. Validasi Data

# %%
df.replace(-9.0, np.nan, inplace=True)
#sesuai dengan soal -9 = null maka di replace

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# num         0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 294 entries, 0 to 293
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       294 non-null    int64
#  1   sex       294 non-null    int64
#  2   cp        294 non-null    int64
#  3   trestbps  294 non-null    object
#  4   chol      294 non-null    object
#  5   fbs       294 non-null    object
#  6   restecg   294 non-null    object
#  7   thalach   294 non-null    object
#  8   exang     294 non-null    object
#  9   oldpeak   294 non-null    float64
#  10  slope     294 non-null    object
#  11  ca        294 non-null    object
#  12  thal      294 non-null    object
#  13  num       294 non-null    int64
# dtypes: float64(1), int64(4), object(9)
# memory usage: 32.3+ KB

# %% [markdown]
# ##4. Menentukan Objek Data

# %% [markdown]
# (1) Kolom 3 (age) </br>
# (2) Kolom 4 (sex) </br>
# (3) Kolom 9 (cp) </br>
# (4) Kolom 10 (trestbps) </br>
# (5) Kolom 12 (chol) </br>
# (6) Kolom 16 (fbs) </br>
# (7) Kolom 19 (restecg) </br>
# (8) Kolom 32 (thalach) </br>
# (9) Kolom 38 (exang) </br>
# (10) Kolom 40 (oldpeak) </br>
# (11) Kolom 41 (slope) </br>
# (12) Kolom 44 (ca) </br>
# (13) Kolom 51 (thal) </br>
# (14) Kolom 58 (num) </br>

# %%
df_selected = df
df_selected.head()
#karena sudah sesuai maka tidak perlu ada perubahan
# Out:
#    age  sex  cp trestbps chol fbs restecg thalach exang  oldpeak slope ca  \
# 0   28    1   2      130  132   0       2     185     0      0.0     ?  ?
# 1   29    1   2      120  243   0       0     160     0      0.0     ?  ?
# 2   29    1   2      140    ?   0       0     170     0      0.0     ?  ?
# 3   30    0   1      170  237   0       1     170     0      0.0     ?  ?
# 4   31    0   2      100  219   0       1     150     0      0.0     ?  ?
#
#   thal  num
# 0    ?    0
# 1    ?    0
# 2    ?    0
# 3    6    0
# 4    ?    0

# %%
df_selected.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 294 entries, 0 to 293
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       294 non-null    int64
#  1   sex       294 non-null    int64
#  2   cp        294 non-null    int64
#  3   trestbps  294 non-null    object
#  4   chol      294 non-null    object
#  5   fbs       294 non-null    object
#  6   restecg   294 non-null    object
#  7   thalach   294 non-null    object
#  8   exang     294 non-null    object
#  9   oldpeak   294 non-null    float64
#  10  slope     294 non-null    object
#  11  ca        294 non-null    object
#  12  thal      294 non-null    object
#  13  num       294 non-null    int64
# dtypes: float64(1), int64(4), object(9)
# memory usage: 32.3+ KB

# %%
df_selected.value_counts()
# Out:
# age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  ca  thal  num
# 49   0    2   110       ?     0    0        160      0      0.0      ?      ?   ?     0      2
# 52   0    4   130       180   0    0        140      1      1.5      2      ?   ?     0      1
# 53   0    3   120       274   0    0        130      0      0.0      ?      ?   ?     0      1
#           2   140       216   0    0        142      1      2.0      2      ?   ?     0      1
#               113       468   ?    0        127      0      0.0      ?      ?   ?     0      1
#                                                                                             ..
# 45   0    2   180       ?     0    0        180      0      0.0      ?      ?   ?     0      1
#               130       237   0    0        170      0      0.0      ?      ?   ?     0      1
# 44   1    4   150       412   0    0        170      0      0.0      ?      ?   ?     0      1
# ...

# %% [markdown]
# ##5. Membersihkan Data

# %%
#Jika kita melihat data diatas pada value counts kita menemukan data yang berisis '?' maka lebih baik di hapus untuk mengoptimalkan
df_selected.replace('?', np.nan, inplace=True)

# %%
df = df.astype(float)

# %%
df_selected.isnull().sum()
# Out:
# age           0
# sex           0
# cp            0
# trestbps      1
# chol         23
# fbs           8
# restecg       1
# thalach       1
# exang         1
# oldpeak       0
# slope       190
# ca          291
# thal        266
# num           0
# dtype: int64

# %%
columns_to_drop = ['ca', 'slope','thal']
#jika dilihat kembali kolom ['ca', 'slope','thal'] memiliki nilai null yang sangat banyak maka lebih baik dihapuskan
df_selected = df_selected.drop(columns_to_drop, axis=1)
df_selected = df_selected.rename(columns={'num': 'target'})
df_selected.isnull().sum()
# Out:
# age          0
# sex          0
# cp           0
# trestbps     1
# chol        23
# fbs          8
# restecg      1
# thalach      1
# exang        1
# oldpeak      0
# target       0
# dtype: int64

# %%
meanTBPS = df_selected['trestbps'].dropna()
meanChol = df_selected['chol'].dropna()
meanfbs = df_selected['fbs'].dropna()
meanRestCG = df_selected['restecg'].dropna()
meanthalach = df_selected['thalach'].dropna()
meanexang = df_selected['exang'].dropna()

# %%
meanTBPS = meanTBPS.astype(float)
meanChol = meanChol.astype(float)
meanfbs = meanfbs.astype(float)
meanthalach = meanthalach.astype(float)
meanexang = meanexang.astype(float)
meanRestCG = meanRestCG.astype(float)

# %%
meanTBPS = round(meanTBPS.mean())
meanChol = round(meanChol.mean())
meanfbs = round(meanfbs.mean())
meanthalach = round(meanthalach.mean())
meanexang = round(meanexang.mean())
meanRestCG = round(meanRestCG.mean())

# %%
fill_values = {'trestbps': meanTBPS, 'chol': meanChol, 'fbs': meanfbs,
              'thalach':meanthalach,'exang':meanexang,'restecg':meanRestCG}
dfClean = df_selected.fillna(value=fill_values)

# %%
dfClean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 294 entries, 0 to 293
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       294 non-null    int64
#  1   sex       294 non-null    int64
#  2   cp        294 non-null    int64
#  3   trestbps  294 non-null    object
#  4   chol      294 non-null    object
#  5   fbs       294 non-null    object
#  6   restecg   294 non-null    object
#  7   thalach   294 non-null    object
#  8   exang     294 non-null    object
#  9   oldpeak   294 non-null    float64
#  10  target    294 non-null    int64
# dtypes: float64(1), int64(4), object(6)
# memory usage: 25.4+ KB

# %%
dfClean.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# target      0
# dtype: int64

# %%
duplicate_rows = dfClean.duplicated()
dfClean[duplicate_rows]
# Out:
#      age  sex  cp trestbps chol fbs restecg thalach exang  oldpeak  target
# 102   49    0   2      110  251   0       0     160     0      0.0       0

# %%
print("All Duplicate Rows:")
dfClean[dfClean.duplicated(keep=False)]
# Out:
# All Duplicate Rows:
#      age  sex  cp trestbps chol fbs restecg thalach exang  oldpeak  target
# 101   49    0   2      110  251   0       0     160     0      0.0       0
# 102   49    0   2      110  251   0       0     160     0      0.0       0

# %%
dfClean = dfClean.drop_duplicates()
print("All Duplicate Rows:")
dfClean[dfClean.duplicated(keep=False)]
# Out:
# All Duplicate Rows:
# Empty DataFrame
# Columns: [age, sex, cp, trestbps, chol, fbs, restecg, thalach, exang, oldpeak, target]
# Index: []

# %%
dfClean.head()
# Out:
#    age  sex  cp trestbps chol fbs restecg thalach exang  oldpeak  target
# 0   28    1   2      130  132   0       2     185     0      0.0       0
# 1   29    1   2      120  243   0       0     160     0      0.0       0
# 2   29    1   2      140  251   0       0     170     0      0.0       0
# 3   30    0   1      170  237   0       1     170     0      0.0       0
# 4   31    0   2      100  219   0       1     150     0      0.0       0

# %%
dfClean['target'].value_counts()
# Out:
# target
# 0    187
# 1    106
# Name: count, dtype: int64

# %%
dfClean.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000  0.014516  0.146616  0.246571  0.087101  0.181130
# sex       0.014516  1.000000  0.245769  0.082064  0.027695  0.044372
# cp        0.146616  0.245769  1.000000  0.081293  0.134697  0.031930
# trestbps  0.246571  0.082064  0.081293  1.000000  0.080818  0.096222
# chol      0.087101  0.027695  0.134697  0.080818  1.000000  0.107686
# fbs       0.181130  0.044372  0.031930  0.096222  0.107686  1.000000
# restecg   0.050672 -0.108656 -0.016372  0.011256  0.048081  0.047988
# thalach  -0.460514 -0.106959 -0.367819 -0.181824 -0.122038 -0.069722
# exang     0.239223  0.154925  0.494674  0.211507  0.161055  0.115503
# oldpeak   0.178172  0.115959  0.351735  0.204000  0.106743  0.063179
# target    0.159860  0.270099  0.504631  0.136744  0.202518  0.162353
#
#            restecg   thalach     exang   oldpeak    target
# age       0.050672 -0.460514  0.239223  0.178172  0.159860
# ...

# %%
cor_mat=dfClean.corr()
fig,ax=plt.subplots(figsize=(15,10))
sns.heatmap(cor_mat,annot=True,linewidths=0.5,fmt=".3f")
# Out:
# <Axes: >

# %% [markdown]
# ##6. Konstruksi Data

# %%
X = dfClean.drop("target",axis=1).values
y = dfClean.iloc[:,-1]

# %%
dfClean['target'].value_counts().plot(kind='bar',figsize=(10,6),color=['green','blue'])
plt.title("Count of the target")
plt.xticks(rotation=0);

# %% [markdown]
# ###Oversampling dengan SMOTE

# %%
from imblearn.over_sampling import SMOTE
# oversampling
smote = SMOTE(random_state=42)
X_smote_resampled, y_smote_resampled = smote.fit_resample(X, y)

# %%
plt.figure(figsize=(12, 4))

# %%
new_df1 = pd.DataFrame(data=y)

# %%
plt.subplot(1, 2, 1)
new_df1.value_counts().plot(kind='bar',figsize=(10,6),color=['green','blue','red','yellow'])
plt.title("target before over sampling with SMOTE ")
plt.xticks(rotation=0);

# %%
plt.subplot(1, 2, 2)
new_df2 = pd.DataFrame(data=y_smote_resampled)

new_df2.value_counts().plot(kind='bar',figsize=(10,6),color=['green','blue','red','yellow'])
plt.title("target after over sampling with SMOTE")
plt.xticks(rotation=0);

plt.tight_layout()
plt.show()

# %%
new_df1 = pd.DataFrame(data=y)
new_df1.value_counts()
# Out:
# target
# 0         187
# 1         106
# Name: count, dtype: int64

# %%
# over
new_df2 = pd.DataFrame(data=y_smote_resampled)
new_df2.value_counts()
# Out:
# target
# 0         187
# 1         187
# Name: count, dtype: int64

# %%
dfClean.describe()
# Out:
#               age         sex          cp     oldpeak      target
# count  293.000000  293.000000  293.000000  293.000000  293.000000
# mean    47.822526    0.726962    2.986348    0.588055    0.361775
# std      7.824875    0.446282    0.965049    0.909554    0.481336
# min     28.000000    0.000000    1.000000    0.000000    0.000000
# 25%     42.000000    0.000000    2.000000    0.000000    0.000000
# 50%     49.000000    1.000000    3.000000    0.000000    0.000000
# 75%     54.000000    1.000000    4.000000    1.000000    1.000000
# max     66.000000    1.000000    4.000000    5.000000    1.000000

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_smote_resampled_normal = scaler.fit_transform(X_smote_resampled)
len(X_smote_resampled_normal)
# Out:
# 374

# %%
dfcek1 = pd.DataFrame(X_smote_resampled_normal)
dfcek1.describe()
# Out:
#                 0           1           2           3           4           5  \
# count  374.000000  374.000000  374.000000  374.000000  374.000000  374.000000
# mean     0.526447    0.762824    0.701524    0.382165    0.333403    0.073139
# std      0.199694    0.415352    0.314285    0.157721    0.139634    0.247071
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.389609    0.638533    0.333333    0.259259    0.249035    0.000000
# 50%      0.552632    1.000000    0.666667    0.351852    0.320463    0.000000
# 75%      0.684211    1.000000    1.000000    0.444444    0.389854    0.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#                 6           7           8           9
# count  374.000000  374.000000  374.000000  374.000000
# mean     0.105304    0.510367    0.376772    0.146242
# std      0.216906    0.217352    0.466474    0.189373
# ...

# %% [markdown]
# ###Split Data

# %%
from sklearn.model_selection import train_test_split

# %%
# membagi fitur dan target menjadi data train dan test (untuk yang oversample saja)
X_train, X_test, y_train, y_test = train_test_split(X_smote_resampled, y_smote_resampled, test_size=0.2, random_state=42,stratify=y_smote_resampled)
# membagi fitur dan target menjadi data train dan test (untuk yang oversample + normalization)
X_train_normal, X_test_normal, y_train_normal, y_test_normal = train_test_split(X_smote_resampled_normal, y_smote_resampled, test_size=0.2, random_state=42,stratify = y_smote_resampled)

# %% [markdown]
# ##7. Pemodelan

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn import tree
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report

# %%
from sklearn.metrics import accuracy_score,recall_score,f1_score,precision_score,roc_auc_score,confusion_matrix,precision_score

# %%
def evaluation(Y_test,Y_pred):
    acc = accuracy_score(Y_test,Y_pred)
    rcl = recall_score(Y_test,Y_pred,average = 'weighted')
    f1 = f1_score(Y_test,Y_pred,average = 'weighted')
    ps = precision_score(Y_test,Y_pred,average = 'weighted')

    metric_dict={'accuracy': round(acc,3), 'recall': round(rcl,3), 'F1 score': round(f1,3), 'Precision score': round(ps,3)}
    return print(metric_dict)

# %% [markdown]
# ###K-Nearest Neighbors

# %%
knn_model = KNeighborsClassifier(n_neighbors = 3)
knn_model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred_knn = knn_model.predict(X_test)
# Evaluate the KNN model
print("K-Nearest Neighbors (KNN) Model:")
accuracy_knn_smote = round(accuracy_score(y_test,y_pred_knn),3)
print("Accuracy:", accuracy_knn_smote)
print("Classification Report:")
print(classification_report(y_test, y_pred_knn))
# Out:
# K-Nearest Neighbors (KNN) Model:
# Accuracy: 0.613
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.64      0.55      0.59        38
#            1       0.60      0.68      0.63        37
#
#     accuracy                           0.61        75
#    macro avg       0.62      0.61      0.61        75
# weighted avg       0.62      0.61      0.61        75

# %%
evaluation(y_test,y_pred_knn)
# Out:
# {'accuracy': 0.613, 'recall': 0.613, 'F1 score': 0.612, 'Precision score': 0.616}

# %%
cm = confusion_matrix(y_test, y_pred_knn)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.title('Confusion Matrix')
plt.xlabel('True')
plt.ylabel('Predict')
plt.show()

# %% [markdown]
# ###Decision Tree

# %%
tree_model = tree.DecisionTreeClassifier()
tree_model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred_tree = tree_model.predict(X_test)
# Evaluate the KNN model
print("Decision Tree Model:")
accuracy_tree_smote = round(accuracy_score(y_test,y_pred_tree),3)
print("Accuracy:", accuracy_tree_smote)
print("Classification Report:")
print(classification_report(y_test, y_pred_tree))
# Out:
# Decision Tree Model:
# Accuracy: 0.733
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.71      0.79      0.75        38
#            1       0.76      0.68      0.71        37
#
#     accuracy                           0.73        75
#    macro avg       0.74      0.73      0.73        75
# weighted avg       0.74      0.73      0.73        75

# %%
evaluation(y_test,y_pred_tree)
# Out:
# {'accuracy': 0.733, 'recall': 0.733, 'F1 score': 0.732, 'Precision score': 0.736}

# %%
cm = confusion_matrix(y_test, y_pred_tree)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.title('Confusion Matrix')
plt.xlabel('True')
plt.ylabel('Predict')
plt.show()

# %% [markdown]
# ###Random Forest

# %%
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred_rf = rf_model.predict(X_test)
# Evaluate the Random Forest model
print("\nRandom Forest Model:")
accuracy_rf_smote = round(accuracy_score(y_test, y_pred_rf),3)
print("Accuracy:",accuracy_rf_smote)
print("Classification Report:")
print(classification_report(y_test, y_pred_rf))
# Out:
# Random Forest Model:
# Accuracy: 0.853
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.89      0.86        38
#            1       0.88      0.81      0.85        37
#
#     accuracy                           0.85        75
#    macro avg       0.86      0.85      0.85        75
# weighted avg       0.86      0.85      0.85        75

# %%
evaluation(y_test,y_pred_rf)
# Out:
# {'accuracy': 0.853, 'recall': 0.853, 'F1 score': 0.853, 'Precision score': 0.855}

# %%
cm = confusion_matrix(y_test, y_pred_rf)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.title('Confusion Matrix')
plt.xlabel('True')
plt.ylabel('Predict')
plt.show()

# %% [markdown]
# ###XGBoost

# %%
xgb_model = XGBClassifier(learning_rate=0.1, n_estimators=100, random_state=42)
xgb_model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, random_state=42, ...)

# %%
y_pred_xgb = xgb_model.predict(X_test)
# Evaluate the XGBoost model
print("\nXGBoost Model:")
accuracy_xgb_smote = round(accuracy_score(y_test, y_pred_xgb),3)
print("Accuracy:",accuracy_xgb_smote)
print("Classification Report:")
print(classification_report(y_test, y_pred_xgb))
# Out:
# XGBoost Model:
# Accuracy: 0.893
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.92      0.90        38
#            1       0.91      0.86      0.89        37
#
#     accuracy                           0.89        75
#    macro avg       0.89      0.89      0.89        75
# weighted avg       0.89      0.89      0.89        75

# %%
evaluation(y_test,y_pred_xgb)
# Out:
# {'accuracy': 0.893, 'recall': 0.893, 'F1 score': 0.893, 'Precision score': 0.894}

# %%
cm = confusion_matrix(y_test, y_pred_xgb)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.title('Confusion Matrix')
plt.xlabel('True')
plt.ylabel('Predict')
plt.show()

# %% [markdown]
# ##8. Evaluasi

# %%
model_comp1 = pd.DataFrame({'Model': ['K-Nearest Neighbour', 'Decision -Tree','Random Forest',
                            'XGBoost'], 'Accuracy': [accuracy_knn_smote*100, accuracy_tree_smote*100,
                            accuracy_rf_smote*100,accuracy_xgb_smote*100]})

# %%
model_comp1.head()
# Out:
#                  Model  Accuracy
# 0  K-Nearest Neighbour      61.3
# 1       Decision -Tree      73.3
# 2        Random Forest      85.3
# 3              XGBoost      89.3

# %%
# Membuat bar plot dengan keterangan jumlah
fig, ax = plt.subplots()
bars = plt.bar(model_comp1['Model'], model_comp1['Accuracy'], color=['red', 'green', 'blue', 'yellow'])
plt.xlabel('Model')
plt.ylabel('Accuracy (%)')
plt.title('Hasil Akurasi Terbaik')
plt.xticks(rotation=45, ha='right') # Untuk memutar label sumbu x agar lebih mudah dibaca

# Menambahkan keterangan jumlah di atas setiap bar
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), ha='center', va='bottom')
plt.show()
